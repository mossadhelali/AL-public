# %% [markdown]
# ## 1. AL-System

# %%
import al
import sklearn.datasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Make Classification Dataset

# %%
X,y = sklearn.datasets.make_classification()
pd.DataFrame(X).describe()
# Out:
#                0           1           2           3           4           5   \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.004479   -0.100366    0.128622   -0.034069   -0.099520    0.083756
# std      0.995555    0.912882    1.297885    1.001474    0.932961    1.065670
# min     -2.135919   -2.844720   -2.582946   -2.857222   -2.235214   -2.934201
# 25%     -0.778946   -0.619174   -0.816218   -0.887267   -0.592417   -0.580318
# 50%      0.035119   -0.120141    0.021727    0.153473   -0.084639    0.271923
# 75%      0.714261    0.499387    1.088035    0.662410    0.472519    0.882845
# max      2.561278    2.286117    3.674479    1.846514    2.588615    2.502630
#
#                6           7           8           9           10          11  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.112797    0.067835   -0.085362   -0.014952    0.031941   -0.040869
# std      0.931826    0.949435    1.000315    1.266385    0.901599    0.999516
# min     -1.873425   -1.775040   -2.178846   -3.367020   -1.625072   -2.933488
# 25%     -0.489670   -0.700918   -0.777407   -0.974004   -0.576013   -0.801057
# 50%      0.074740   -0.031818   -0.060850   -0.070159   -0.083584   -0.028607
# 75%      0.756352    0.631612    0.454695    0.976428    0.676726    0.718211
# max      2.716573    3.136392    2.788119    2.562388    2.891333    1.875560
#
#                12          13          14          15          16          17  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    -0.054896    0.041397   -0.205236   -0.058407    0.078961   -0.014182
# std      1.132147    1.085143    1.063120    1.011749    0.810270    1.048100
# min     -2.856049   -2.960981   -2.457541   -1.948769   -1.448460   -2.666478
# 25%     -0.736246   -0.633084   -0.927668   -0.907069   -0.594172   -0.617948
# 50%     -0.055001    0.107538   -0.081662   -0.146684    0.035252    0.048577
# 75%      0.710718    0.673021    0.426850    0.504232    0.611981    0.473732
# max      3.398184    2.828137    2.776167    2.777851    2.642960    2.874841
#
#                18          19
# count  100.000000  100.000000
# mean    -0.085212   -0.075813
# std      0.958429    0.806745
# min     -2.390909   -2.804048
# 25%     -0.585686   -0.606507
# 50%     -0.109020   -0.057669
# 75%      0.486178    0.489671
# max      2.536880    1.500867

# %%
print(len(X))
# Out:
# 100

# %%
m = al.AL()
m.fit(X, y)
progs = m.get_programs()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/26 [00:00<?, ?it/s]
# Generating transforms
# Programs of depth=0
# Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  12%|█▏        | 3/26 [00:00<00:00, 26.67it/s]Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  23%|██▎       | 6/26 [00:00<00:00, 24.85it/s]Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  31%|███       | 8/26 [00:00<00:00, 19.81it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  38%|███▊      | 10/26 [00:00<00:00, 19.38it/s]Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  46%|████▌     | 12/26 [00:00<00:00, 18.64it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  54%|█████▍    | 14/26 [00:00<00:00, 18.67it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  62%|██████▏   | 16/26 [00:00<00:00, 17.08it/s]Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  69%|██████▉   | 18/26 [00:01<00:00, 14.23it/s]Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  77%|███████▋  | 20/26 [00:01<00:00, 14.30it/s]Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  96%|█████████▌| 25/26 [00:01<00:00, 16.61it/s]Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
# 100%|██████████| 1/1 [00:01<00:00,  1.59s/it]s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(sklearn.preprocessing.data.StandardScaler): None
# Failed to apply transform(sklearn.preprocessing.data.StandardScaler): <class 'synthesis.runtime_helpers.ColumnLoop'>
# [Transforms] Pruning programs of depth 0
# Programs of depth=1
# Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  12%|█▏        | 3/26 [00:00<00:00, 28.02it/s]Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  23%|██▎       | 6/26 [00:00<00:00, 28.60it/s]Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  31%|███       | 8/26 [00:00<00:00, 22.41it/s]Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  42%|████▏     | 11/26 [00:00<00:00, 23.62it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  50%|█████     | 13/26 [00:00<00:00, 20.95it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  58%|█████▊    | 15/26 [00:00<00:00, 20.44it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  65%|██████▌   | 17/26 [00:01<00:00, 13.99it/s]Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  73%|███████▎  | 19/26 [00:01<00:00, 14.20it/s]Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  81%|████████  | 21/26 [00:01<00:00, 14.09it/s]Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  96%|█████████▌| 25/26 [00:01<00:00, 15.52it/s]Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
#  10%|█         | 1/10 [00:01<00:15,  1.74s/it]]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(sklearn.preprocessing.data.StandardScaler): None
# Failed to apply transform(sklearn.preprocessing.data.StandardScaler): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#   8%|▊         | 2/26 [00:00<00:01, 15.09it/s]Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  23%|██▎       | 6/26 [00:00<00:00, 20.38it/s]Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  31%|███       | 8/26 [00:00<00:01, 16.46it/s]Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  38%|███▊      | 10/26 [00:00<00:01, 15.97it/s]Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  46%|████▌     | 12/26 [00:00<00:00, 14.61it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  54%|█████▍    | 14/26 [00:00<00:00, 14.74it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  62%|██████▏   | 16/26 [00:01<00:00, 12.78it/s]Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  69%|██████▉   | 18/26 [00:01<00:00, 10.39it/s]
#  73%|███████▎  | 19/26 [00:01<00:00, 10.26it/s]
#  77%|███████▋  | 20/26 [00:01<00:00, 10.22it/s]Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  88%|████████▊ | 23/26 [00:02<00:00, 10.92it/s]Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
# 100%|██████████| 26/26 [00:02<00:00, 11.64it/s]
#  20%|██        | 2/10 [00:04<00:16,  2.02s/it]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
#   8%|▊         | 2/26 [00:00<00:01, 14.19it/s]Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  19%|█▉        | 5/26 [00:00<00:01, 20.71it/s]Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  27%|██▋       | 7/26 [00:00<00:01, 18.17it/s]Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): None
# Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  38%|███▊      | 10/26 [00:00<00:00, 18.36it/s]Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  50%|█████     | 13/26 [00:00<00:00, 18.88it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  58%|█████▊    | 15/26 [00:00<00:00, 17.85it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  65%|██████▌   | 17/26 [00:00<00:00, 17.34it/s]Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  73%|███████▎  | 19/26 [00:01<00:00, 16.58it/s]
#  81%|████████  | 21/26 [00:01<00:00, 16.19it/s]Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  96%|█████████▌| 25/26 [00:01<00:00, 17.84it/s]Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  30%|███       | 3/10 [00:05<00:12,  1.85s/it]]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  15%|█▌        | 4/26 [00:00<00:00, 32.21it/s]Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  23%|██▎       | 6/26 [00:00<00:00, 23.33it/s]Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  31%|███       | 8/26 [00:00<00:00, 21.00it/s]Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  42%|████▏     | 11/26 [00:00<00:00, 20.75it/s]Failed to apply transform(sklearn.preprocessing.imputation.Imputer): None
# Failed to apply transform(sklearn.preprocessing.imputation.Imputer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  58%|█████▊    | 15/26 [00:00<00:00, 21.98it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  65%|██████▌   | 17/26 [00:01<00:00, 15.82it/s]Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  73%|███████▎  | 19/26 [00:01<00:00, 16.14it/s]Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  81%|████████  | 21/26 [00:01<00:00, 16.37it/s]Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
# 100%|██████████| 26/26 [00:01<00:00, 18.30it/s]
#  40%|████      | 4/10 [00:07<00:10,  1.75s/it]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  15%|█▌        | 4/26 [00:00<00:00, 29.13it/s]Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  23%|██▎       | 6/26 [00:00<00:00, 22.05it/s]Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  31%|███       | 8/26 [00:00<00:00, 20.36it/s]Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  42%|████▏     | 11/26 [00:00<00:00, 20.64it/s]Failed to apply transform(sklearn.preprocessing.imputation.Imputer): None
# Failed to apply transform(sklearn.preprocessing.imputation.Imputer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  54%|█████▍    | 14/26 [00:00<00:00, 21.90it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  62%|██████▏   | 16/26 [00:00<00:00, 18.84it/s]Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  69%|██████▉   | 18/26 [00:01<00:00, 15.38it/s]
#  77%|███████▋  | 20/26 [00:01<00:00, 15.41it/s]Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  92%|█████████▏| 24/26 [00:01<00:00, 17.13it/s]Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
#  50%|█████     | 5/10 [00:08<00:08,  1.71s/it]]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  12%|█▏        | 3/26 [00:00<00:00, 26.39it/s]Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  23%|██▎       | 6/26 [00:00<00:00, 22.51it/s]Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  31%|███       | 8/26 [00:00<00:00, 20.99it/s]Failed to apply transform(sklearn.decomposition.pca.PCA): None
# Failed to apply transform(sklearn.decomposition.pca.PCA): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  46%|████▌     | 12/26 [00:00<00:00, 23.11it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  58%|█████▊    | 15/26 [00:00<00:00, 22.51it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  65%|██████▌   | 17/26 [00:01<00:00, 13.94it/s]Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  73%|███████▎  | 19/26 [00:01<00:00, 13.84it/s]Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  81%|████████  | 21/26 [00:01<00:00, 13.86it/s]Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  96%|█████████▌| 25/26 [00:01<00:00, 15.32it/s]Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
#  60%|██████    | 6/10 [00:10<00:06,  1.71s/it]]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  12%|█▏        | 3/26 [00:00<00:01, 22.89it/s]Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  23%|██▎       | 6/26 [00:00<00:00, 20.10it/s]Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.decomposition.pca.PCA): None
# Failed to apply transform(sklearn.decomposition.pca.PCA): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  38%|███▊      | 10/26 [00:00<00:00, 24.18it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  46%|████▌     | 12/26 [00:00<00:00, 17.91it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  54%|█████▍    | 14/26 [00:00<00:00, 17.31it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  62%|██████▏   | 16/26 [00:00<00:00, 16.40it/s]Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  69%|██████▉   | 18/26 [00:01<00:00, 12.42it/s]
#  77%|███████▋  | 20/26 [00:01<00:00, 12.14it/s]Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  88%|████████▊ | 23/26 [00:01<00:00, 12.99it/s]Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
# 100%|██████████| 26/26 [00:01<00:00, 13.78it/s]
#  70%|███████   | 7/10 [00:12<00:05,  1.75s/it]
#   0%|          | 0/26 [00:00<?, ?it/s]
# Failed computing missing
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#   8%|▊         | 2/26 [00:00<00:01, 19.59it/s]Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  15%|█▌        | 4/26 [00:00<00:01, 17.41it/s]Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  19%|█▉        | 5/26 [00:00<00:01, 13.21it/s]Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.imputation.Imputer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  27%|██▋       | 7/26 [00:00<00:01, 11.73it/s]Failed to apply transform(sklearn.preprocessing.data.StandardScaler): None
# Failed to apply transform(sklearn.preprocessing.data.StandardScaler): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  31%|███       | 8/26 [00:00<00:01, 11.39it/s]Failed to apply transform(sklearn.decomposition.pca.PCA): None
# Failed to apply transform(sklearn.decomposition.pca.PCA): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  38%|███▊      | 10/26 [00:00<00:01, 12.49it/s]Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.variance_threshold.VarianceThreshold): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  58%|█████▊    | 15/26 [00:01<00:00, 14.48it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  65%|██████▌   | 17/26 [00:01<00:00, 13.87it/s]Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  73%|███████▎  | 19/26 [00:01<00:00, 12.33it/s]Failed to apply transform(sklearn.preprocessing.data.PolynomialFeatures): None
# Failed to apply transform(sklearn.preprocessing.data.PolynomialFeatures): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.MinMaxScaler): None
# Failed to apply transform(sklearn.preprocessing.data.MinMaxScaler): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  81%|████████  | 21/26 [00:01<00:00, 12.69it/s]Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
# 100%|██████████| 26/26 [00:01<00:00, 14.44it/s]
#  80%|████████  | 8/10 [00:14<00:03,  1.76s/it]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  12%|█▏        | 3/26 [00:00<00:00, 25.44it/s]Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  23%|██▎       | 6/26 [00:00<00:00, 20.72it/s]Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  31%|███       | 8/26 [00:00<00:00, 18.98it/s]Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  42%|████▏     | 11/26 [00:00<00:00, 19.10it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  50%|█████     | 13/26 [00:00<00:00, 18.38it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  58%|█████▊    | 15/26 [00:00<00:00, 18.02it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  65%|██████▌   | 17/26 [00:01<00:00, 12.95it/s]Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#  73%|███████▎  | 19/26 [00:01<00:00, 13.22it/s]Failed to apply transform(sklearn.feature_selection.variance_threshold.VarianceThreshold): None
# Failed to apply transform(sklearn.feature_selection.variance_threshold.VarianceThreshold): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  88%|████████▊ | 23/26 [00:01<00:00, 14.78it/s]Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
# 100%|██████████| 26/26 [00:01<00:00, 15.69it/s]
#  90%|█████████ | 9/10 [00:15<00:01,  1.75s/it]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  12%|█▏        | 3/26 [00:00<00:01, 21.85it/s]Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  23%|██▎       | 6/26 [00:00<00:00, 21.00it/s]Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  31%|███       | 8/26 [00:00<00:00, 19.31it/s]Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  42%|████▏     | 11/26 [00:00<00:00, 18.64it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  50%|█████     | 13/26 [00:00<00:00, 18.01it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  58%|█████▊    | 15/26 [00:00<00:00, 17.78it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  65%|██████▌   | 17/26 [00:01<00:00, 12.92it/s]Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  73%|███████▎  | 19/26 [00:01<00:00, 13.25it/s]Failed to apply transform(sklearn.feature_selection.variance_threshold.VarianceThreshold): None
# Failed to apply transform(sklearn.feature_selection.variance_threshold.VarianceThreshold): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  88%|████████▊ | 23/26 [00:01<00:00, 14.92it/s]Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# ...
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  77%|███████▋  | 20/26 [00:01<00:00, 19.37it/s]
#  85%|████████▍ | 22/26 [00:01<00:00, 18.41it/s]Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
# 100%|██████████| 26/26 [00:01<00:00, 19.89it/s]
# 100%|██████████| 10/10 [00:17<00:00,  1.71s/it]
#   0%|          | 0/31 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
# [Transforms] Pruning programs of depth 2
# Generating modeling
# Failed to apply model: builtins.module
#
#  12%|█▎        | 4/32 [00:00<00:01, 23.73it/s]Failed to apply model: xgboost.core.Booster
#
#  22%|██▏       | 7/32 [00:00<00:00, 25.57it/s]
#  31%|███▏      | 10/32 [00:00<00:01, 21.85it/s]
#   3%|▎         | 1/31 [00:00<00:24,  1.21it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]/home/mosemos/anaconda2/envs/al/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#   3%|▎         | 1/32 [00:00<00:12,  2.51it/s]Failed to apply model: builtins.module
#
#  12%|█▎        | 4/32 [00:00<00:03,  7.89it/s]
#  22%|██▏       | 7/32 [00:00<00:02,  9.82it/s]Failed to apply model: xgboost.core.Booster
#
#  34%|███▍      | 11/32 [00:01<00:01, 10.57it/s]
#   6%|▋         | 2/31 [00:02<00:30,  1.04s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]/home/mosemos/anaconda2/envs/al/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#   3%|▎         | 1/32 [00:00<00:15,  2.00it/s]Failed to apply model: builtins.module
#
#  19%|█▉        | 6/32 [00:00<00:02,  9.74it/s]
#  25%|██▌       | 8/32 [00:00<00:02, 10.65it/s]Failed to apply model: xgboost.core.Booster
#
#  34%|███▍      | 11/32 [00:00<00:01, 11.30it/s]
#  10%|▉         | 3/31 [00:03<00:30,  1.09s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]
#  12%|█▎        | 4/32 [00:00<00:00, 29.82it/s]Failed to apply model: builtins.module
#
#  22%|██▏       | 7/32 [00:00<00:00, 27.98it/s]Failed to apply model: xgboost.core.Booster
# /home/mosemos/anaconda2/envs/al/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#  13%|█▎        | 4/31 [00:03<00:26,  1.04it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#  12%|█▎        | 4/32 [00:00<00:00, 38.78it/s]Failed to apply model: builtins.module
#
#  25%|██▌       | 8/32 [00:00<00:00, 31.50it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:01, 21.60it/s]/home/mosemos/anaconda2/envs/al/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#  16%|█▌        | 5/31 [00:04<00:24,  1.06it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#  12%|█▎        | 4/32 [00:00<00:00, 35.12it/s]Failed to apply model: builtins.module
#
#  25%|██▌       | 8/32 [00:00<00:00, 26.12it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:01, 18.91it/s]/home/mosemos/anaconda2/envs/al/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#  19%|█▉        | 6/31 [00:05<00:23,  1.06it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  12%|█▎        | 4/32 [00:00<00:00, 28.54it/s]
#  25%|██▌       | 8/32 [00:00<00:00, 25.06it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:01, 18.76it/s]/home/mosemos/anaconda2/envs/al/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#  23%|██▎       | 7/31 [00:06<00:23,  1.02it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   3%|▎         | 1/32 [00:00<00:03,  9.47it/s]
#   9%|▉         | 3/32 [00:00<00:02, 13.28it/s]Failed to apply model: builtins.module
#
#  19%|█▉        | 6/32 [00:00<00:01, 14.30it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:01, 13.67it/s]/home/mosemos/anaconda2/envs/al/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#  26%|██▌       | 8/31 [00:08<00:23,  1.04s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]
# Failed computing missing
# Failed to apply model: builtins.module
#
#   9%|▉         | 3/32 [00:00<00:01, 17.21it/s]
#  16%|█▌        | 5/32 [00:00<00:02, 10.52it/s]
#  28%|██▊       | 9/32 [00:00<00:02, 11.07it/s]Failed to apply model: xgboost.core.Booster
#
#  29%|██▉       | 9/31 [00:09<00:22,  1.04s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#   9%|▉         | 3/32 [00:00<00:01, 26.41it/s]
#  16%|█▌        | 5/32 [00:00<00:01, 22.34it/s]
#  22%|██▏       | 7/32 [00:00<00:01, 18.47it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:01, 15.29it/s]/home/mosemos/anaconda2/envs/al/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#  32%|███▏      | 10/31 [00:10<00:22,  1.05s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  12%|█▎        | 4/32 [00:00<00:01, 26.12it/s]
#  19%|█▉        | 6/32 [00:00<00:01, 22.72it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:01, 21.63it/s]/home/mosemos/anaconda2/envs/al/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#  35%|███▌      | 11/31 [00:11<00:20,  1.04s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   9%|▉         | 3/32 [00:00<00:01, 25.28it/s]
#  19%|█▉        | 6/32 [00:00<00:00, 27.29it/s]Failed to apply model: builtins.module
#
#  25%|██▌       | 8/32 [00:00<00:01, 23.93it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:01, 18.33it/s]
#  39%|███▊      | 12/31 [00:12<00:19,  1.01s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]
#  12%|█▎        | 4/32 [00:00<00:00, 36.93it/s]Failed to apply model: builtins.module
#
#  25%|██▌       | 8/32 [00:00<00:00, 27.89it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:01, 20.06it/s]
#  42%|████▏     | 13/31 [00:12<00:17,  1.02it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#  12%|█▎        | 4/32 [00:00<00:00, 37.83it/s]Failed to apply model: builtins.module
#
#  25%|██▌       | 8/32 [00:00<00:00, 31.21it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:00, 23.36it/s]
#  45%|████▌     | 14/31 [00:13<00:16,  1.05it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#  12%|█▎        | 4/32 [00:00<00:00, 35.24it/s]Failed to apply model: builtins.module
#
#  25%|██▌       | 8/32 [00:00<00:00, 28.59it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:01, 20.95it/s]
#  48%|████▊     | 15/31 [00:13<00:14,  1.08it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
# /home/mosemos/anaconda2/envs/al/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#   9%|▉         | 3/32 [00:00<00:02, 10.64it/s]
#  22%|██▏       | 7/32 [00:00<00:01, 15.35it/s]Failed to apply model: xgboost.core.Booster
#
#  34%|███▍      | 11/32 [00:00<00:01, 16.29it/s]
#  52%|█████▏    | 16/31 [00:14<00:13,  1.09it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
# /home/mosemos/anaconda2/envs/al/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#   9%|▉         | 3/32 [00:00<00:04,  6.68it/s]
#  16%|█▌        | 5/32 [00:00<00:03,  8.94it/s]
#  22%|██▏       | 7/32 [00:00<00:02,  9.59it/s]Failed to apply model: xgboost.core.Booster
#
#  34%|███▍      | 11/32 [00:01<00:02, 10.18it/s]
#  55%|█████▍    | 17/31 [00:15<00:13,  1.07it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
# /home/mosemos/anaconda2/envs/al/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#   9%|▉         | 3/32 [00:00<00:04,  6.81it/s]
#  16%|█▌        | 5/32 [00:00<00:02,  9.18it/s]
#  22%|██▏       | 7/32 [00:00<00:02,  9.93it/s]Failed to apply model: xgboost.core.Booster
#
#  34%|███▍      | 11/32 [00:01<00:01, 10.91it/s]
#  58%|█████▊    | 18/31 [00:17<00:12,  1.05it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
# /home/mosemos/anaconda2/envs/al/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#   9%|▉         | 3/32 [00:00<00:04,  6.95it/s]
#  16%|█▌        | 5/32 [00:00<00:02,  9.21it/s]
#  22%|██▏       | 7/32 [00:00<00:02, 10.15it/s]Failed to apply model: xgboost.core.Booster
#
#  34%|███▍      | 11/32 [00:00<00:01, 11.06it/s]
#  61%|██████▏   | 19/31 [00:18<00:11,  1.04it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   9%|▉         | 3/32 [00:00<00:01, 24.52it/s]Failed to apply model: builtins.module
#
#  19%|█▉        | 6/32 [00:00<00:01, 22.78it/s]
#  25%|██▌       | 8/32 [00:00<00:01, 20.21it/s]Failed to apply model: xgboost.core.Booster
#
#  65%|██████▍   | 20/31 [00:18<00:10,  1.06it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#  12%|█▎        | 4/32 [00:00<00:00, 31.03it/s]Failed to apply model: builtins.module
#
#  22%|██▏       | 7/32 [00:00<00:00, 29.61it/s]Failed to apply model: xgboost.core.Booster
#
#  68%|██████▊   | 21/31 [00:19<00:09,  1.09it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  16%|█▌        | 5/32 [00:00<00:00, 47.01it/s]
#  25%|██▌       | 8/32 [00:00<00:00, 31.31it/s]Failed to apply model: xgboost.core.Booster
#
#  71%|███████   | 22/31 [00:19<00:08,  1.12it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  16%|█▌        | 5/32 [00:00<00:00, 48.73it/s]
#  25%|██▌       | 8/32 [00:00<00:00, 33.11it/s]Failed to apply model: xgboost.core.Booster
#
#  74%|███████▍  | 23/31 [00:20<00:06,  1.15it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  16%|█▌        | 5/32 [00:00<00:00, 47.51it/s]
#  25%|██▌       | 8/32 [00:00<00:00, 30.61it/s]Failed to apply model: xgboost.core.Booster
#
#  77%|███████▋  | 24/31 [00:20<00:05,  1.17it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  16%|█▌        | 5/32 [00:00<00:00, 47.20it/s]
#  25%|██▌       | 8/32 [00:00<00:00, 31.35it/s]Failed to apply model: xgboost.core.Booster
#
#  81%|████████  | 25/31 [00:20<00:05,  1.20it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  12%|█▎        | 4/32 [00:00<00:00, 38.91it/s]Failed to apply model: xgboost.core.Booster
#
#  22%|██▏       | 7/32 [00:00<00:01, 22.06it/s]
#  28%|██▊       | 9/32 [00:00<00:01, 18.17it/s]
#  84%|████████▍ | 26/31 [00:21<00:04,  1.21it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  16%|█▌        | 5/32 [00:00<00:00, 30.71it/s]Failed to apply model: xgboost.core.Booster
#
#  22%|██▏       | 7/32 [00:00<00:01, 21.44it/s]
#  28%|██▊       | 9/32 [00:00<00:01, 19.06it/s]
#  87%|████████▋ | 27/31 [00:22<00:03,  1.22it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  16%|█▌        | 5/32 [00:00<00:00, 46.65it/s]
#  22%|██▏       | 7/32 [00:00<00:00, 29.09it/s]Failed to apply model: xgboost.core.Booster
#
#  28%|██▊       | 9/32 [00:00<00:01, 22.30it/s]
#  90%|█████████ | 28/31 [00:22<00:02,  1.23it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  12%|█▎        | 4/32 [00:00<00:00, 32.32it/s]
#  19%|█▉        | 6/32 [00:00<00:00, 26.46it/s]Failed to apply model: xgboost.core.Booster
#  25%|██▌       | 8/32 [00:00<00:01, 22.07it/s]
#  31%|███▏      | 10/32 [00:00<00:01, 16.33it/s]
#  94%|█████████▎| 29/31 [00:23<00:01,  1.24it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   6%|▋         | 2/32 [00:00<00:01, 18.83it/s]Failed to apply model: builtins.module
#
#  19%|█▉        | 6/32 [00:00<00:00, 26.59it/s]Failed to apply model: xgboost.core.Booster
#
#  25%|██▌       | 8/32 [00:00<00:01, 22.02it/s]
#  31%|███▏      | 10/32 [00:00<00:01, 15.84it/s]
#  97%|█████████▋| 30/31 [00:24<00:00,  1.23it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#   9%|▉         | 3/32 [00:00<00:00, 29.10it/s]
#  19%|█▉        | 6/32 [00:00<00:00, 26.25it/s]Failed to apply model: xgboost.core.Booster
#
#  25%|██▌       | 8/32 [00:00<00:01, 20.73it/s]
#  31%|███▏      | 10/32 [00:00<00:01, 14.94it/s]
# 100%|██████████| 31/31 [00:25<00:00,  1.23it/s]
#   0%|          | 0/40 [00:00<?, ?it/s]
# [Model] Pruning programs of depth 0
# [Model] Pruning programs of depth 1
# [Model] Pruning programs of depth 2
# [Model] Pruning programs of depth 3
# Adding test data
# Failed to add test data, program depth: 0
#  32%|███▎      | 13/40 [00:00<00:00, 27.01it/s]Failed to add test data, program depth: 1
# Failed to add test data, program depth: 1
#  82%|████████▎ | 33/40 [00:01<00:00, 18.90it/s]Failed to add test data, program depth: 3
#  88%|████████▊ | 35/40 [00:01<00:00, 18.85it/s]Failed to add test data, program depth: 3
# Failed to add test data, program depth: 3
# Failed to add test data, program depth: 3
# 100%|██████████| 40/40 [00:02<00:00, 18.77it/s]
#  55%|█████▍    | 18/33 [00:00<00:00, 29.92it/s]/home/mosemos/anaconda2/envs/al/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
# 100%|██████████| 33/33 [00:03<00:00,  9.58it/s]
#  35%|███▌      | 11/31 [00:00<00:00, 86.78it/s]
# Fitting programs found on entire training set
#  68%|██████▊   | 21/31 [00:00<00:00, 33.44it/s]/home/mosemos/anaconda2/envs/al/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
# 100%|██████████| 31/31 [00:03<00:00,  8.13it/s]

# %%
print("Number of Programs:", len(progs))
# Out:
# Number of Programs: 31

# %%
dir(progs[0])
# Out:
# ['__class__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add_model',
#  'add_test_data',
#  'add_transform',
#  'code',
#  'copy_with_sharing',
#  'depth',
#  'fit_final',
#  'imports',
#  'imports_code',
#  'instr_id',
#  'log_prob',
#  'model_',
#  'ops',
#  'pipeline_code',
#  'predict',
#  'predict_proba',
#  'score',
#  'score_',
#  'state',
#  'trace']

# %%
print("Score:", progs[0].score_)
print("Depth:", progs[0].depth)
# Out:
# Score: 1.0
# Depth: 0

# %%
print(progs[0].pipeline_code())
# Out:
# import sklearn
# import sklearn.linear_model.logistic
# import xgboost
#
# from sklearn.pipeline import Pipeline
# p = Pipeline([('model', sklearn.linear_model.logistic.LogisticRegression())])
# p.fit(X_train, y_train)
# print(p.score(X_val, y_val))
# p.fit(X, y)
# def predict(X_test): return p.predict(X_test)

# %%
print("Score:", progs[-10].score_)
print("Depth:", progs[-10].depth)
# Out:
# Score: 0.79797979798
# Depth: 1

# %%
print(progs[-10].pipeline_code())
# Out:
# import sklearn
# import sklearn.neural_network.multilayer_perceptron
# import sklearn.preprocessing.data
# import xgboost
#
# from sklearn.pipeline import Pipeline
# p = Pipeline([('t0', sklearn.preprocessing.data.StandardScaler()),('model', sklearn.neural_network.multilayer_perceptron.MLPClassifier())])
# p.fit(X_train, y_train)
# print(p.score(X_val, y_val))
# p.fit(X, y)
# def predict(X_test): return p.predict(X_test)

# %%
scores = [i.score_ for i in progs]
depths = [i.depth for i in progs]
plt.plot(scores, depths)
plt.xlabel('Pipeline Score')
plt.ylabel('Pipeline Depth')
plt.show()

# %% [markdown]
# ### Boston Housing Dataset

# %%
X, y = sklearn.datasets.load_boston(return_X_y=True)
pd.DataFrame(X).describe()
# Out:
#                0           1           2           3           4           5   \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.593761   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.596783   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.647423   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#                6           7           8           9           10          11  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#                12
# count  506.000000
# mean    12.653063
# std      7.141062
# min      1.730000
# 25%      6.950000
# 50%     11.360000
# 75%     16.955000
# max     37.970000

# %%
print(len(X))
# Out:
# 506

# %%
m.fit(X, y)
progs_boston = m.get_programs()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/26 [00:00<?, ?it/s]
# Generating transforms
# Programs of depth=0
# Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  15%|█▌        | 4/26 [00:00<00:00, 27.69it/s]Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  27%|██▋       | 7/26 [00:00<00:00, 21.01it/s]Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  38%|███▊      | 10/26 [00:00<00:00, 18.74it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  50%|█████     | 13/26 [00:00<00:00, 18.38it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  58%|█████▊    | 15/26 [00:00<00:00, 17.28it/s]Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  65%|██████▌   | 17/26 [00:01<00:00, 15.51it/s]Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  81%|████████  | 21/26 [00:01<00:00, 16.84it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
#  88%|████████▊ | 23/26 [00:01<00:00, 16.95it/s]Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
# 100%|██████████| 26/26 [00:01<00:00, 17.79it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.54s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(sklearn.preprocessing.data.StandardScaler): None
# Failed to apply transform(sklearn.preprocessing.data.StandardScaler): <class 'synthesis.runtime_helpers.ColumnLoop'>
# [Transforms] Pruning programs of depth 0
# Programs of depth=1
# Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  19%|█▉        | 5/26 [00:00<00:00, 31.61it/s]Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  27%|██▋       | 7/26 [00:00<00:00, 22.11it/s]Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  35%|███▍      | 9/26 [00:00<00:00, 20.60it/s]Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  46%|████▌     | 12/26 [00:00<00:00, 21.59it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  54%|█████▍    | 14/26 [00:00<00:00, 19.42it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  62%|██████▏   | 16/26 [00:00<00:00, 19.00it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  69%|██████▉   | 18/26 [00:01<00:00, 16.12it/s]Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  77%|███████▋  | 20/26 [00:01<00:00, 16.23it/s]Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  88%|████████▊ | 23/26 [00:01<00:00, 17.22it/s]Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  10%|█         | 1/10 [00:01<00:13,  1.52s/it]]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(sklearn.preprocessing.data.StandardScaler): None
# Failed to apply transform(sklearn.preprocessing.data.StandardScaler): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#   8%|▊         | 2/26 [00:00<00:01, 18.78it/s]Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  19%|█▉        | 5/26 [00:00<00:00, 24.00it/s]Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  27%|██▋       | 7/26 [00:00<00:01, 17.04it/s]Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  35%|███▍      | 9/26 [00:00<00:01, 15.82it/s]Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  42%|████▏     | 11/26 [00:00<00:00, 15.75it/s]Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  50%|█████     | 13/26 [00:00<00:00, 14.97it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  58%|█████▊    | 15/26 [00:01<00:00, 14.91it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  65%|██████▌   | 17/26 [00:01<00:00, 13.92it/s]Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  73%|███████▎  | 19/26 [00:01<00:00, 12.03it/s]Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  81%|████████  | 21/26 [00:01<00:00, 12.51it/s]Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  88%|████████▊ | 23/26 [00:01<00:00, 12.76it/s]Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
# 100%|██████████| 26/26 [00:01<00:00, 13.53it/s]
#  20%|██        | 2/10 [00:03<00:14,  1.76s/it]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#   8%|▊         | 2/26 [00:00<00:01, 18.34it/s]Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  15%|█▌        | 4/26 [00:00<00:01, 16.55it/s]Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): None
# Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  27%|██▋       | 7/26 [00:00<00:00, 19.50it/s]Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  38%|███▊      | 10/26 [00:00<00:00, 20.51it/s]Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  46%|████▌     | 12/26 [00:00<00:00, 19.82it/s]Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
#  54%|█████▍    | 14/26 [00:00<00:00, 18.51it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  65%|██████▌   | 17/26 [00:00<00:00, 18.18it/s]Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  73%|███████▎  | 19/26 [00:01<00:00, 17.28it/s]Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  81%|████████  | 21/26 [00:01<00:00, 16.87it/s]Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  96%|█████████▌| 25/26 [00:01<00:00, 18.30it/s]
#  30%|███       | 3/10 [00:05<00:11,  1.69s/it]]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#   8%|▊         | 2/26 [00:00<00:01, 16.98it/s]Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  19%|█▉        | 5/26 [00:00<00:01, 19.65it/s]Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  27%|██▋       | 7/26 [00:00<00:01, 15.18it/s]Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.imputation.Imputer): None
# Failed to apply transform(sklearn.preprocessing.imputation.Imputer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  38%|███▊      | 10/26 [00:00<00:00, 17.17it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  50%|█████     | 13/26 [00:00<00:00, 17.44it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  58%|█████▊    | 15/26 [00:00<00:00, 15.01it/s]Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  69%|██████▉   | 18/26 [00:01<00:00, 16.29it/s]Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  81%|████████  | 21/26 [00:01<00:00, 16.84it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
#  92%|█████████▏| 24/26 [00:01<00:00, 17.50it/s]Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  40%|████      | 4/10 [00:06<00:09,  1.66s/it]]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  15%|█▌        | 4/26 [00:00<00:00, 30.71it/s]Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  23%|██▎       | 6/26 [00:00<00:00, 24.37it/s]Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.imputation.Imputer): None
# Failed to apply transform(sklearn.preprocessing.imputation.Imputer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  38%|███▊      | 10/26 [00:00<00:00, 24.44it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  50%|█████     | 13/26 [00:00<00:00, 22.73it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  58%|█████▊    | 15/26 [00:00<00:00, 17.56it/s]Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  69%|██████▉   | 18/26 [00:00<00:00, 18.73it/s]Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  81%|████████  | 21/26 [00:01<00:00, 19.00it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
#  92%|█████████▏| 24/26 [00:01<00:00, 19.76it/s]Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  50%|█████     | 5/10 [00:08<00:08,  1.61s/it]]
#   0%|          | 0/26 [00:00<?, ?it/s]
# Failed computing missing
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  12%|█▏        | 3/26 [00:00<00:01, 22.39it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  19%|█▉        | 5/26 [00:00<00:01, 17.74it/s]Failed to apply transform(sklearn.preprocessing.data.StandardScaler): None
# Failed to apply transform(sklearn.preprocessing.data.StandardScaler): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.imputation.Imputer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  27%|██▋       | 7/26 [00:00<00:01, 16.20it/s]Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.decomposition.pca.PCA): None
# Failed to apply transform(sklearn.decomposition.pca.PCA): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  35%|███▍      | 9/26 [00:00<00:01, 16.64it/s]Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  54%|█████▍    | 14/26 [00:00<00:00, 20.98it/s]Failed to apply transform(sklearn.feature_selection.variance_threshold.VarianceThreshold): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.MinMaxScaler): None
# Failed to apply transform(sklearn.preprocessing.data.MinMaxScaler): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  65%|██████▌   | 17/26 [00:00<00:00, 19.56it/s]Failed to apply transform(sklearn.preprocessing.data.PolynomialFeatures): None
# Failed to apply transform(sklearn.preprocessing.data.PolynomialFeatures): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  73%|███████▎  | 19/26 [00:01<00:00, 18.51it/s]Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  81%|████████  | 21/26 [00:01<00:00, 16.70it/s]Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  96%|█████████▌| 25/26 [00:01<00:00, 18.37it/s]Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  60%|██████    | 6/10 [00:09<00:06,  1.58s/it]]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#   8%|▊         | 2/26 [00:00<00:01, 18.19it/s]Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  19%|█▉        | 5/26 [00:00<00:01, 20.33it/s]Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  27%|██▋       | 7/26 [00:00<00:01, 16.33it/s]Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  35%|███▍      | 9/26 [00:00<00:01, 15.92it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  42%|████▏     | 11/26 [00:00<00:01, 14.35it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  50%|█████     | 13/26 [00:00<00:00, 13.85it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  58%|█████▊    | 15/26 [00:01<00:00, 11.11it/s]Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  69%|██████▉   | 18/26 [00:01<00:00, 11.92it/s]Failed to apply transform(sklearn.feature_selection.variance_threshold.VarianceThreshold): None
# Failed to apply transform(sklearn.feature_selection.variance_threshold.VarianceThreshold): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  81%|████████  | 21/26 [00:01<00:00, 12.88it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
#  92%|█████████▏| 24/26 [00:01<00:00, 13.39it/s]Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
# 100%|██████████| 26/26 [00:01<00:00, 13.63it/s]
#  70%|███████   | 7/10 [00:11<00:04,  1.65s/it]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#   8%|▊         | 2/26 [00:00<00:01, 17.78it/s]Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  19%|█▉        | 5/26 [00:00<00:01, 19.54it/s]Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  27%|██▋       | 7/26 [00:00<00:01, 16.09it/s]Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  35%|███▍      | 9/26 [00:00<00:01, 15.72it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  42%|████▏     | 11/26 [00:00<00:01, 14.18it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  50%|█████     | 13/26 [00:00<00:00, 13.77it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  58%|█████▊    | 15/26 [00:01<00:00, 11.11it/s]Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  69%|██████▉   | 18/26 [00:01<00:00, 11.90it/s]Failed to apply transform(sklearn.feature_selection.variance_threshold.VarianceThreshold): None
# Failed to apply transform(sklearn.feature_selection.variance_threshold.VarianceThreshold): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  81%|████████  | 21/26 [00:01<00:00, 12.85it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
#  92%|█████████▏| 24/26 [00:01<00:00, 13.26it/s]Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
# 100%|██████████| 26/26 [00:01<00:00, 13.46it/s]
#  80%|████████  | 8/10 [00:13<00:03,  1.69s/it]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#   8%|▊         | 2/26 [00:00<00:01, 13.56it/s]
#  12%|█▏        | 3/26 [00:00<00:02, 10.25it/s]Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  15%|█▌        | 4/26 [00:01<00:07,  2.85it/s]Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  23%|██▎       | 6/26 [00:02<00:06,  2.98it/s]Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  35%|███▍      | 9/26 [00:02<00:04,  3.65it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  42%|████▏     | 11/26 [00:02<00:03,  4.19it/s]Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  54%|█████▍    | 14/26 [00:02<00:02,  5.14it/s]Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  62%|██████▏   | 16/26 [00:02<00:01,  5.62it/s]Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.PolynomialFeatures): None
# Failed to apply transform(sklearn.preprocessing.data.PolynomialFeatures): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  73%|███████▎  | 19/26 [00:02<00:01,  6.34it/s]Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
#  85%|████████▍ | 22/26 [00:03<00:00,  7.06it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  96%|█████████▌| 25/26 [00:03<00:00,  7.35it/s]
#  90%|█████████ | 9/10 [00:17<00:01,  1.92s/it]]
#   0%|          | 0/26 [00:00<?, ?it/s]
#   8%|▊         | 2/26 [00:00<00:01, 12.59it/s]Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  15%|█▌        | 4/26 [00:00<00:01, 14.71it/s]Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  23%|██▎       | 6/26 [00:01<00:04,  4.89it/s]Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  31%|███       | 8/26 [00:01<00:03,  5.15it/s]Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  38%|███▊      | 10/26 [00:01<00:02,  5.37it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  46%|████▌     | 12/26 [00:02<00:02,  5.87it/s]Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  54%|█████▍    | 14/26 [00:02<00:01,  6.52it/s]Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  65%|██████▌   | 17/26 [00:02<00:01,  7.49it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.PolynomialFeatures): None
# Failed to apply transform(sklearn.preprocessing.data.PolynomialFeatures): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  77%|███████▋  | 20/26 [00:02<00:00,  8.41it/s]Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
# Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  85%|████████▍ | 22/26 [00:02<00:00,  8.85it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# ...
#
#  48%|████▊     | 15/31 [01:17<01:22,  5.18s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: sklearn.svm.classes.SVC
# Failed to apply model: sklearn.ensemble.forest.RandomForestClassifier
# Failed to apply model: builtins.module
#
#  16%|█▌        | 5/32 [00:00<00:00, 40.32it/s]Failed to apply model: xgboost.core.Booster
# Failed to apply model: sklearn.neighbors.classification.KNeighborsClassifier
#
#  31%|███▏      | 10/32 [00:00<00:00, 39.17it/s]Failed to apply model: sklearn.grid_search.GridSearchCV
# Failed to apply model: sklearn.naive_bayes.BernoulliNB
#
#  47%|████▋     | 15/32 [00:00<00:00, 37.79it/s]Failed to apply model: sklearn.svm.classes.LinearSVC
# Failed to apply model: sklearn.naive_bayes.GaussianNB
# Failed to apply model: sklearn.multiclass.OneVsRestClassifier
#
#  52%|█████▏    | 16/31 [01:18<01:13,  4.90s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: sklearn.svm.classes.SVC
# Failed to apply model: sklearn.ensemble.forest.RandomForestClassifier
# Failed to apply model: builtins.module
#
#  16%|█▌        | 5/32 [00:00<00:00, 29.67it/s]
#  22%|██▏       | 7/32 [00:00<00:00, 26.01it/s]Failed to apply model: xgboost.core.Booster
# Failed to apply model: sklearn.neighbors.classification.KNeighborsClassifier
# Failed to apply model: sklearn.grid_search.GridSearchCV
#
#  38%|███▊      | 12/32 [00:00<00:00, 30.72it/s]Failed to apply model: sklearn.naive_bayes.BernoulliNB
#
#  47%|████▋     | 15/32 [00:00<00:00, 25.59it/s]Failed to apply model: sklearn.svm.classes.LinearSVC
# Failed to apply model: sklearn.naive_bayes.GaussianNB
#
#  56%|█████▋    | 18/32 [00:00<00:00, 25.89it/s]Failed to apply model: sklearn.multiclass.OneVsRestClassifier
#
#  55%|█████▍    | 17/31 [01:19<01:05,  4.67s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: sklearn.ensemble.forest.RandomForestClassifier
# Failed to apply model: builtins.module
# Failed to apply model: sklearn.svm.classes.SVC
#
#  16%|█▌        | 5/32 [00:00<00:00, 33.89it/s]
#  22%|██▏       | 7/32 [00:00<00:01, 23.25it/s]Failed to apply model: xgboost.core.Booster
# Failed to apply model: sklearn.neighbors.classification.KNeighborsClassifier
#
#  34%|███▍      | 11/32 [00:00<00:00, 27.67it/s]Failed to apply model: sklearn.grid_search.GridSearchCV
# Failed to apply model: sklearn.naive_bayes.BernoulliNB
#
#  47%|████▋     | 15/32 [00:00<00:00, 24.78it/s]Failed to apply model: sklearn.naive_bayes.GaussianNB
#
#  53%|█████▎    | 17/32 [00:00<00:00, 22.62it/s]
#  58%|█████▊    | 18/31 [01:20<00:58,  4.47s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: sklearn.ensemble.forest.RandomForestClassifier
# Failed to apply model: builtins.module
# Failed to apply model: sklearn.svm.classes.SVC
#
#  16%|█▌        | 5/32 [00:00<00:00, 32.60it/s]
#  22%|██▏       | 7/32 [00:00<00:01, 22.32it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:00, 23.53it/s]Failed to apply model: sklearn.neighbors.classification.KNeighborsClassifier
# Failed to apply model: sklearn.grid_search.GridSearchCV
# Failed to apply model: sklearn.naive_bayes.BernoulliNB
#
#  44%|████▍     | 14/32 [00:00<00:00, 26.41it/s]Failed to apply model: sklearn.naive_bayes.GaussianNB
#
#  53%|█████▎    | 17/32 [00:00<00:00, 20.80it/s]
#  61%|██████▏   | 19/31 [01:21<00:51,  4.30s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
# Failed to apply model: sklearn.ensemble.forest.RandomForestClassifier
# Failed to apply model: sklearn.svm.classes.LinearSVC
# Failed to apply model: sklearn.svm.classes.SVC
#
#  16%|█▌        | 5/32 [00:00<00:00, 49.26it/s]Failed to apply model: xgboost.core.Booster
#
#  25%|██▌       | 8/32 [00:00<00:00, 26.39it/s]Failed to apply model: sklearn.grid_search.GridSearchCV
#
#  31%|███▏      | 10/32 [00:00<00:00, 23.57it/s]Failed to apply model: sklearn.naive_bayes.BernoulliNB
#
#  38%|███▊      | 12/32 [00:00<00:00, 20.96it/s]Failed to apply model: sklearn.neighbors.classification.KNeighborsClassifier
#
#  50%|█████     | 16/32 [00:00<00:00, 21.08it/s]Failed to apply model: sklearn.multiclass.OneVsRestClassifier
# Failed to apply model: sklearn.naive_bayes.GaussianNB
#
#  59%|█████▉    | 19/32 [00:00<00:00, 21.81it/s]Failed to apply model: sklearn.ensemble.gradient_boosting.GradientBoostingClassifier
# Failed to apply model: sklearn.linear_model.logistic.LogisticRegression
# Failed to apply model: sklearn.ensemble.voting_classifier.VotingClassifier
# Failed to apply model: sklearn.tree.tree.DecisionTreeClassifier
#
#  65%|██████▍   | 20/31 [01:22<00:45,  4.14s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
# Failed to apply model: sklearn.ensemble.forest.RandomForestClassifier
# Failed to apply model: sklearn.svm.classes.LinearSVC
# Failed to apply model: sklearn.svm.classes.SVC
# Failed to apply model: xgboost.core.Booster
#
#  25%|██▌       | 8/32 [00:00<00:00, 44.48it/s]Failed to apply model: sklearn.grid_search.GridSearchCV
#
#  34%|███▍      | 11/32 [00:00<00:00, 36.48it/s]Failed to apply model: sklearn.naive_bayes.BernoulliNB
# Failed to apply model: sklearn.neighbors.classification.KNeighborsClassifier
#
#  50%|█████     | 16/32 [00:00<00:00, 30.84it/s]Failed to apply model: sklearn.multiclass.OneVsRestClassifier
# Failed to apply model: sklearn.naive_bayes.GaussianNB
#
#  59%|█████▉    | 19/32 [00:00<00:00, 29.94it/s]Failed to apply model: sklearn.ensemble.gradient_boosting.GradientBoostingClassifier
# Failed to apply model: sklearn.linear_model.logistic.LogisticRegression
# Failed to apply model: sklearn.ensemble.voting_classifier.VotingClassifier
# Failed to apply model: sklearn.tree.tree.DecisionTreeClassifier
#
#  68%|██████▊   | 21/31 [01:23<00:39,  3.98s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
# Failed to apply model: sklearn.ensemble.forest.RandomForestClassifier
#
#  12%|█▎        | 4/32 [00:00<00:00, 39.06it/s]
#  19%|█▉        | 6/32 [00:00<00:00, 27.22it/s]Failed to apply model: xgboost.core.Booster
# Failed to apply model: sklearn.neighbors.classification.KNeighborsClassifier
#
#  31%|███▏      | 10/32 [00:00<00:00, 29.75it/s]
#  38%|███▊      | 12/32 [00:00<00:00, 26.39it/s]Failed to apply model: sklearn.svm.classes.SVC
# Failed to apply model: sklearn.ensemble.gradient_boosting.GradientBoostingClassifier
# Failed to apply model: sklearn.naive_bayes.BernoulliNB
# Failed to apply model: sklearn.grid_search.GridSearchCV
#
#  71%|███████   | 22/31 [01:24<00:34,  3.83s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
# Failed to apply model: sklearn.ensemble.forest.RandomForestClassifier
#
#  12%|█▎        | 4/32 [00:00<00:00, 33.55it/s]
#  19%|█▉        | 6/32 [00:00<00:01, 23.96it/s]Failed to apply model: xgboost.core.Booster
# Failed to apply model: sklearn.neighbors.classification.KNeighborsClassifier
#
#  31%|███▏      | 10/32 [00:00<00:00, 27.06it/s]
#  38%|███▊      | 12/32 [00:00<00:00, 24.72it/s]Failed to apply model: sklearn.svm.classes.SVC
# Failed to apply model: sklearn.ensemble.gradient_boosting.GradientBoostingClassifier
# Failed to apply model: sklearn.naive_bayes.BernoulliNB
# Failed to apply model: sklearn.grid_search.GridSearchCV
#
#  74%|███████▍  | 23/31 [01:24<00:29,  3.69s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
# Failed to apply model: sklearn.ensemble.forest.RandomForestClassifier
# Failed to apply model: sklearn.svm.classes.SVC
#
#  16%|█▌        | 5/32 [00:00<00:00, 39.42it/s]
#  22%|██▏       | 7/32 [00:00<00:00, 28.98it/s]Failed to apply model: xgboost.core.Booster
# Failed to apply model: sklearn.neighbors.classification.KNeighborsClassifier
#
#  34%|███▍      | 11/32 [00:00<00:00, 31.21it/s]Failed to apply model: sklearn.ensemble.gradient_boosting.GradientBoostingClassifier
#
#  44%|████▍     | 14/32 [00:00<00:00, 27.59it/s]Failed to apply model: sklearn.naive_bayes.BernoulliNB
# Failed to apply model: sklearn.grid_search.GridSearchCV
#
#  77%|███████▋  | 24/31 [01:25<00:24,  3.57s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
# Failed to apply model: sklearn.ensemble.forest.RandomForestClassifier
# Failed to apply model: sklearn.svm.classes.SVC
#
#  16%|█▌        | 5/32 [00:00<00:00, 36.84it/s]
#  22%|██▏       | 7/32 [00:00<00:00, 25.42it/s]Failed to apply model: xgboost.core.Booster
# Failed to apply model: sklearn.neighbors.classification.KNeighborsClassifier
#
#  34%|███▍      | 11/32 [00:00<00:00, 28.43it/s]
#  41%|████      | 13/32 [00:00<00:00, 24.61it/s]Failed to apply model: sklearn.ensemble.gradient_boosting.GradientBoostingClassifier
# Failed to apply model: sklearn.naive_bayes.BernoulliNB
# Failed to apply model: sklearn.grid_search.GridSearchCV
#
#  81%|████████  | 25/31 [01:26<00:20,  3.45s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: sklearn.ensemble.forest.RandomForestClassifier
# Failed to apply model: builtins.module
# Failed to apply model: sklearn.svm.classes.LinearSVC
# Failed to apply model: sklearn.svm.classes.SVC
#
#  19%|█▉        | 6/32 [00:00<00:00, 47.85it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:00, 42.91it/s]Failed to apply model: sklearn.neighbors.classification.KNeighborsClassifier
# Failed to apply model: sklearn.grid_search.GridSearchCV
# Failed to apply model: sklearn.naive_bayes.BernoulliNB
#
#  47%|████▋     | 15/32 [00:00<00:00, 44.36it/s]Failed to apply model: sklearn.naive_bayes.GaussianNB
#
#  56%|█████▋    | 18/32 [00:00<00:00, 34.91it/s]
#  84%|████████▍ | 26/31 [01:26<00:16,  3.35s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: sklearn.ensemble.forest.RandomForestClassifier
# Failed to apply model: builtins.module
# Failed to apply model: sklearn.svm.classes.LinearSVC
# Failed to apply model: sklearn.svm.classes.SVC
#
#  19%|█▉        | 6/32 [00:00<00:00, 53.90it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:00, 44.52it/s]Failed to apply model: sklearn.neighbors.classification.KNeighborsClassifier
# Failed to apply model: sklearn.grid_search.GridSearchCV
# Failed to apply model: sklearn.naive_bayes.BernoulliNB
#
#  44%|████▍     | 14/32 [00:00<00:00, 43.01it/s]
#  53%|█████▎    | 17/32 [00:00<00:00, 34.97it/s]Failed to apply model: sklearn.naive_bayes.GaussianNB
#
#  87%|████████▋ | 27/31 [01:27<00:12,  3.25s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: sklearn.ensemble.forest.RandomForestClassifier
# Failed to apply model: builtins.module
# Failed to apply model: sklearn.svm.classes.LinearSVC
# Failed to apply model: sklearn.svm.classes.SVC
#
#  19%|█▉        | 6/32 [00:00<00:00, 51.60it/s]Failed to apply model: xgboost.core.Booster
#
#  34%|███▍      | 11/32 [00:00<00:00, 42.57it/s]Failed to apply model: sklearn.neighbors.classification.KNeighborsClassifier
# Failed to apply model: sklearn.grid_search.GridSearchCV
# Failed to apply model: sklearn.naive_bayes.BernoulliNB
#
#  50%|█████     | 16/32 [00:00<00:00, 39.04it/s]Failed to apply model: sklearn.naive_bayes.GaussianNB
#
#  90%|█████████ | 28/31 [01:28<00:09,  3.16s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: sklearn.ensemble.forest.RandomForestClassifier
# Failed to apply model: builtins.module
# Failed to apply model: sklearn.svm.classes.LinearSVC
# Failed to apply model: sklearn.svm.classes.SVC
#
#  19%|█▉        | 6/32 [00:00<00:00, 54.42it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:00, 45.52it/s]Failed to apply model: sklearn.neighbors.classification.KNeighborsClassifier
# Failed to apply model: sklearn.grid_search.GridSearchCV
# Failed to apply model: sklearn.naive_bayes.BernoulliNB
#
#  47%|████▋     | 15/32 [00:00<00:00, 46.15it/s]Failed to apply model: sklearn.naive_bayes.GaussianNB
#
#  56%|█████▋    | 18/32 [00:00<00:00, 35.85it/s]
#  94%|█████████▎| 29/31 [01:29<00:06,  3.07s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: sklearn.ensemble.forest.RandomForestClassifier
# Failed to apply model: builtins.module
# Failed to apply model: sklearn.svm.classes.LinearSVC
# Failed to apply model: sklearn.svm.classes.SVC
# Failed to apply model: xgboost.core.Booster
#
#  22%|██▏       | 7/32 [00:00<00:00, 38.10it/s]Failed to apply model: sklearn.grid_search.GridSearchCV
# Failed to apply model: sklearn.naive_bayes.BernoulliNB
#
#  34%|███▍      | 11/32 [00:00<00:00, 33.24it/s]Failed to apply model: sklearn.neighbors.classification.KNeighborsClassifier
#
#  47%|████▋     | 15/32 [00:00<00:00, 28.78it/s]Failed to apply model: sklearn.ensemble.gradient_boosting.GradientBoostingClassifier
# Failed to apply model: sklearn.multiclass.OneVsRestClassifier
#
#  59%|█████▉    | 19/32 [00:00<00:00, 30.19it/s]Failed to apply model: sklearn.naive_bayes.GaussianNB
# Failed to apply model: sklearn.linear_model.logistic.LogisticRegression
# Failed to apply model: sklearn.ensemble.voting_classifier.VotingClassifier
# Failed to apply model: sklearn.tree.tree.DecisionTreeClassifier
# Failed to apply model: sklearn.ensemble.forest.ExtraTreesClassifier
# Failed to apply model: sklearn.naive_bayes.MultinomialNB
#
#  78%|███████▊  | 25/32 [00:00<00:00, 33.30it/s]
#  97%|█████████▋| 30/31 [01:30<00:03,  3.00s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: sklearn.ensemble.forest.RandomForestClassifier
# Failed to apply model: builtins.module
# Failed to apply model: sklearn.svm.classes.LinearSVC
# Failed to apply model: sklearn.svm.classes.SVC
# Failed to apply model: xgboost.core.Booster
#
#  22%|██▏       | 7/32 [00:00<00:00, 38.14it/s]Failed to apply model: sklearn.grid_search.GridSearchCV
# Failed to apply model: sklearn.naive_bayes.BernoulliNB
#
#  34%|███▍      | 11/32 [00:00<00:00, 33.35it/s]Failed to apply model: sklearn.neighbors.classification.KNeighborsClassifier
#
#  47%|████▋     | 15/32 [00:00<00:00, 22.64it/s]Failed to apply model: sklearn.ensemble.gradient_boosting.GradientBoostingClassifier
# Failed to apply model: sklearn.multiclass.OneVsRestClassifier
#
#  59%|█████▉    | 19/32 [00:00<00:00, 21.87it/s]Failed to apply model: sklearn.naive_bayes.GaussianNB
# Failed to apply model: sklearn.linear_model.logistic.LogisticRegression
# Failed to apply model: sklearn.ensemble.voting_classifier.VotingClassifier
# Failed to apply model: sklearn.tree.tree.DecisionTreeClassifier
# Failed to apply model: sklearn.ensemble.forest.ExtraTreesClassifier
#
#  75%|███████▌  | 24/32 [00:00<00:00, 24.39it/s]Failed to apply model: sklearn.naive_bayes.MultinomialNB
#
# 100%|██████████| 31/31 [01:31<00:00,  2.94s/it]
#   0%|          | 0/40 [00:00<?, ?it/s]
# [Model] Pruning programs of depth 0
# [Model] Pruning programs of depth 1
# [Model] Pruning programs of depth 2
# [Model] Pruning programs of depth 3
# Adding test data
# Failed to add test data, program depth: 0
#  25%|██▌       | 10/40 [00:00<00:01, 28.59it/s]Failed to add test data, program depth: 1
# Failed to add test data, program depth: 1
#  38%|███▊      | 15/40 [00:00<00:01, 23.13it/s]Failed to add test data, program depth: 1
# Failed to add test data, program depth: 1
#  45%|████▌     | 18/40 [00:00<00:00, 22.87it/s]Failed to add test data, program depth: 1
# Failed to add test data, program depth: 2
#  52%|█████▎    | 21/40 [00:00<00:00, 22.13it/s]Failed to add test data, program depth: 2
# Failed to add test data, program depth: 2
#  57%|█████▊    | 23/40 [00:01<00:00, 21.32it/s]Failed to add test data, program depth: 2
#  72%|███████▎  | 29/40 [00:01<00:00, 19.47it/s]Failed to add test data, program depth: 3
#  78%|███████▊  | 31/40 [00:01<00:00, 18.84it/s]Failed to add test data, program depth: 3
# Failed to add test data, program depth: 3
#  82%|████████▎ | 33/40 [00:01<00:00, 18.30it/s]Failed to add test data, program depth: 3
# Failed to add test data, program depth: 3
#  88%|████████▊ | 35/40 [00:01<00:00, 17.65it/s]Failed to add test data, program depth: 3
# Failed to add test data, program depth: 3
#  92%|█████████▎| 37/40 [00:02<00:00, 16.94it/s]Failed to add test data, program depth: 3
# Failed to add test data, program depth: 3
#  98%|█████████▊| 39/40 [00:02<00:00, 16.41it/s]Failed to add test data, program depth: 3
# 100%|██████████| 40/40 [00:02<00:00, 16.08it/s]
# 100%|██████████| 20/20 [00:01<00:00, 10.46it/s]
# 0it [00:00, ?it/s]
# Fitting programs found on entire training set

# %%
len(progs_boston)
# Out:
# 0
